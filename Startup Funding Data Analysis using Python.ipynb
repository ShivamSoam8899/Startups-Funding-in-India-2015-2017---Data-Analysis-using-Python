# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
with open(r"C:\Users\Shivam Soam\Desktop\Data Science CN\Datasets CN\startup_funding - Copy.csv") as file_obj:
    file_data = csv.DictReader(file_obj,skipinitialspace=True)
    Year=[]
    for row in file_data:
        Year.append(row['Date'].split('/'))
correct_year=[]
for i in range(0,len(Year)):
    if len(Year[i])==3:
        correct_year.append(Year[i][2])
correct_year=np.array(correct_year)
dic= dict()
for i in correct_year:
    if i in dic.keys():
        dic[i]+=1
    else:
        dic[i]=1
dic=dict(sorted(dic.items()))
print(dic)
xaxis=[]
yaxis=[]
for row in dic:
    xaxis.append(row)
    yaxis.append(dic[row])
xaxis=np.array(xaxis)
yaxis=np.array(yaxis)
plt.plot(xaxis,yaxis,label="No of Funding per Year")
plt.xlabel("Year")
plt.ylabel("No of Fundings")
plt.legend()
plt.show()
print(2015 , 936)
print(2016 , 993)
print(2017 , 443)
# Out:
# {'2015': 931, '2016': 993, '2017': 443}
# 2015 936
# 2016 993
# 2017 443

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
with open(r"C:\Users\Shivam Soam\Desktop\Data Science CN\Datasets CN\startup_funding - Copy.csv") as file_obj:
    file_data = csv.DictReader(file_obj,skipinitialspace=True)
    City=[]
    for row in file_data:
        if row['CityLocation']!='':
            City.append(row['CityLocation'].split('/')[0].strip())
dic =dict()
for i in City:
    if i == "bangalore":
        i="Bangalore"
    if i == "Delhi":
        i="New Delhi"
    if i in dic.keys():
        dic[i]+=1
    else:
        dic[i]=1
d_swap = {v: k for k, v in dic.items()}
d_swap=dict(sorted(d_swap.items()))
number_of_startup=[]
startup_city=[]
for row in d_swap:
    number_of_startup.append(row)
    startup_city.append(d_swap[row])
startup_count=[]
top_city=[]
for i in range(-10,0,1):
    startup_count.append(number_of_startup[i])
    top_city.append(startup_city[i])
explode =[]
for i in range(0,len(startup_count)):
    explode.append(0.5)
plt.pie(startup_count,radius=2,explode=explode,labels=top_city,autopct="%.2f",startangle=100)
plt.show()
for i in range(-1,-11,-1):
    print(top_city[i] , startup_count[i])
# Out:
# Bangalore 635
# Mumbai 449
# New Delhi 389
# Gurgaon 241
# Pune 91
# Noida 79
# Hyderabad 77
# Chennai 67
# Ahmedabad 35
# Jaipur 25

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
with open(r"C:\Users\Shivam Soam\Desktop\Data Science CN\Datasets CN\startup_funding - Copy.csv") as file_obj:
    file_data = csv.DictReader(file_obj,skipinitialspace=True)
    City=[]
    Amount_Fund=[]
    for row in file_data:
        if row['CityLocation']!='':
            City.append(row['CityLocation'].split('/')[0].strip())
            if row['AmountInUSD']=='':
                row['AmountInUSD']=str(0)
            Amount_Fund.append(row['AmountInUSD'].replace(',',""))
City = np.array(City)
Amount_Fund=np.array(Amount_Fund , dtype='int64')
dic=dict()
for i in range(len(City)):
    if City[i] == "bangalore":
        City[i]="Bangalore"
    if City[i] == "Delhi":
        City[i]="New Delhi"
    if City[i] in dic:
        dic[City[i]]+=Amount_Fund[i]
    else:
        dic[City[i]]=Amount_Fund[i]
dic = {v: k for k, v in dic.items()}
dic=dict(sorted(dic.items()))
xaxis=list(dic.values())
yaxis=list(dic.keys())

np_xaxis=np.array(xaxis)
np_yaxis=np.array(yaxis)
x_axis=[]
y_axis=[]

for i in range(-1,-11,-1):
    x_axis.append(np_xaxis[i])
    y_axis.append(np_yaxis[i])
explode=[]
for i in range(0,len(y_axis)):
    explode.append(0.5)
plt.pie(y_axis,explode=explode,radius=3,labels=x_axis,autopct="%.2f")
plt.show()
for i in range(0,len(x_axis)):
    print(x_axis[i],format((y_axis[i]*100/sum(y_axis)),'.2f'))
# Out:
# Bangalore 49.71
# New Delhi 16.63
# Mumbai 13.90
# Gurgaon 12.21
# Chennai 2.43
# Pune 2.16
# Hyderabad 1.15
# Noida 1.01
# Ahmedabad 0.58
# Jaipur 0.21

# %%
original_data=pd.read_csv(r"C:\Users\Shivam Soam\Desktop\Data Science CN\Datasets CN\startup_funding - Copy.csv", encoding='utf8')
df=original_data.copy()
df.AmountInUSD.fillna('0', inplace=True)
df.InvestmentType.loc[df.InvestmentType=='Crowd funding']='Crowd Funding'
df.InvestmentType.loc[df.InvestmentType=='PrivateEquity']='Private Equity'
df.InvestmentType.loc[df.InvestmentType=='SeedFunding']='Seed Funding'


np_seed_funding=np.array(df.AmountInUSD[df.InvestmentType=='Seed Funding'])
for i in range(len(np_seed_funding)):
    np_seed_funding[i]=''.join(np_seed_funding[i].split(','))
np_seed_funding=np.array(np_seed_funding, dtype='int64')


np_Crowd_Funding=np.array(df.AmountInUSD[df.InvestmentType=='Crowd Funding'])
for i in range(len(np_Crowd_Funding)):
    np_Crowd_Funding[i]=''.join(np_Crowd_Funding[i].split(','))
np_Crowd_Funding=np.array(np_Crowd_Funding, dtype='int64')


np_Debt_Funding=np.array(df.AmountInUSD[df.InvestmentType=='Debt Funding'])
for i in range(len(np_Debt_Funding)):
    np_Debt_Funding[i]=''.join(np_Debt_Funding[i].split(','))
np_Debt_Funding=np.array(np_Debt_Funding, dtype='int64')


np_Private_Equity=np.array(df.AmountInUSD[df.InvestmentType=='Private Equity'])
for i in range(len(np_Private_Equity)):
    np_Private_Equity[i]=''.join(np_Private_Equity[i].split(','))
np_Private_Equity=np.array(np_Private_Equity, dtype='int64')

private=sum(np_Private_Equity)
crowd=sum(np_Crowd_Funding)
debt=sum(np_Debt_Funding)
seed=sum(np_seed_funding)
xaxis=['Private Equity', 'Seed Funding', 'Debt Funding', 'Crowd Funding']
yaxis=[private, seed, debt, crowd]

plt.subplots(figsize=(15, 10))
plt.scatter(xaxis, yaxis, s=100, color='red', alpha=0.5)
plt.xticks(size=16)
plt.yticks(size=16)
plt.xlabel('Investment Type--->', size=16)
plt.ylabel('Number of Investments--->', size=16)
plt.title('Investment Type Bubble Chart')
for i in range(len(xaxis)):
    plt.text(xaxis[i], yaxis[i], yaxis[i], size=16)
plt.show()

for i in range(len(xaxis)):
    print(xaxis[i],format((yaxis[i]*100)/sum(yaxis), '.5f'))
# Out:
# C:\Users\Shivam Soam\AppData\Local\Temp\ipykernel_23756\1467642140.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.InvestmentType.loc[df.InvestmentType=='Crowd funding']='Crowd Funding'
# C:\Users\Shivam Soam\AppData\Local\Temp\ipykernel_23756\1467642140.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.InvestmentType.loc[df.InvestmentType=='PrivateEquity']='Private Equity'
# C:\Users\Shivam Soam\AppData\Local\Temp\ipykernel_23756\1467642140.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
with open(r"C:\Users\Shivam Soam\Desktop\Data Science CN\Datasets CN\startup_funding - Copy.csv") as file_obj:
    file_data = csv.DictReader(file_obj,skipinitialspace=True)
    Industry=[]
    Amount=[]
    for row in file_data:
        if row['IndustryVertical']!='':
            if row['IndustryVertical']=="eCommerce" or row['IndustryVertical']=="ECommerce" or row['IndustryVertical']=="ecommerce":
                row['IndustryVertical']="Ecommerce"
            Industry.append(row['IndustryVertical'])
            if row['AmountInUSD']=="":
                row['AmountInUSD']=str(0)
            Amount.append(row['AmountInUSD'].replace(',',""))
Industry = np.array(Industry)
Amount = np.array(Amount,dtype='int64')

dic = dict()
for i in range(len(Industry)):
    if Industry[i] in dic:
        dic[Industry[i]]+=Amount[i]
    else:
        dic[Industry[i]]=Amount[i]

dic = {v: k for k, v in dic.items()}
dic=dict(sorted(dic.items()))
xaxis=list(dic.values())
yaxis=list(dic.keys())

np_xaxis=np.array(xaxis)
np_yaxis=np.array(yaxis)
top_5_Industry=[]
top_5_Amount=[]
for i in range(-1,-6,-1):
    top_5_Industry.append(np_xaxis[i])
    top_5_Amount.append(np_yaxis[i])
explode =[]
for i in range(0,len(top_5_Amount)):
    explode.append(0.1)
plt.pie(top_5_Amount,radius=2,explode=explode,autopct="%.2f")
plt.show()
for i in range(0,len(top_5_Industry)):
    print(top_5_Industry[i],format((top_5_Amount[i]*100)/sum(top_5_Amount),'.2f'))
# Out:
# Ecommerce 40.53
# Consumer Internet 35.95
# Technology 10.45
# Online Marketplace 6.63
# E-Commerce & M-Commerce platform 6.44

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
with open(r"C:\Users\Shivam Soam\Desktop\Data Science CN\Datasets CN\startup_funding - Copy.csv") as file_obj:
    file_data = csv.DictReader(file_obj,skipinitialspace=True)
    startup_list=[]
    amount_list=[]
    for row in file_data:
        startup_list.append(row['StartupName'])
        if row['AmountInUSD']=='':
            row['AmountInUSD']='0'
        amount_list.append(row['AmountInUSD'].replace(",",""))
startups=[]
for row in startup_list:
    if 'Ola' in row :
        row ='Ola'
    if 'Flipkart' in row :
        row ='Flipkart'
    if 'Oyo' in row :
        row ='Oyo'
    if 'Paytm' in row :
        row ='Paytm'
    startups.append(row)
startupsnp= np.array(startups)
amountnp=np.array(amount_list, dtype="int64")
dic = dict()
for i in range(0,len(startupsnp)):
    if startupsnp[i] in dic.keys():
        dic[startupsnp[i]]+=amountnp[i]
    else:
        dic[startupsnp[i]]=amountnp[i]
dic={v: k for k, v in dic.items()}
dic=dict(sorted(dic.items()))
total_startups=[]
for row in dic:
    total_startups.append(dic[row])
for i in range(-1,-6,-1):
    print(total_startups[i])
# Out:
# Paytm
# Flipkart
# Ola
# Snapdeal
# Oyo

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
with open(r"C:\Users\Shivam Soam\Desktop\Data Science CN\Datasets CN\startup_funding - Copy.csv") as file_obj:
    file_data = csv.DictReader(file_obj,skipinitialspace=True)
    startup_list=[]
    amount_list=[]
    for row in file_data:
        startup_list.append(row['StartupName'])
        if row['AmountInUSD']=='':
            row['AmountInUSD']='0'
        amount_list.append(row['AmountInUSD'].replace(",",""))
startups=[]
for row in startup_list:
    if 'Ola' in row :
        row ='Ola'
    if 'Flipkart' in row :
        row ='Flipkart'
    if 'Oyo' in row :
        row ='Oyo'
    if 'Paytm' in row :
        row ='Paytm'
    startups.append(row)
startupsnp= np.array(startups)
amountnp=np.array(amount_list, dtype="int64")
dic = dict()
for i in range(0,len(startupsnp)):
    if startupsnp[i] in dic.keys():
        dic[startupsnp[i]]+=amountnp[i]
    else:
        dic[startupsnp[i]]=amountnp[i]
dic={v: k for k, v in dic.items()}
dic=dict(sorted(dic.items()))
total_startups=[]
amount_per_startup=[]
for row in dic:
    total_startups.append(dic[row])
    amount_per_startup.append(row)
for i in range(-1,-6,-1):
    print(total_startups[i])
top_20st=[]
top_20am=[]
for i in range(-1,-21,-1):
    top_20st.append(total_startups[i])
    top_20am.append(amount_per_startup[i])
explode=[]
for i in range(0,len(top_20am)):
    explode.append(0.4)
plt.pie(top_20am,explode=explode,radius=3,labels=top_20st,autopct="%.2f")
plt.show()
# Out:
# Paytm
# Flipkart
# Ola
# Snapdeal
# Oyo
